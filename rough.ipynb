# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
x=np.random.randint(1,100,1000)
y=np.random.randint(40,99,1000)
plt.scatter(x,y)

# %%
def linear(w1,w2,b1,x,y):
    return w1*x+w2*y+b1

# %%
def sigmoid(z):
    return 1/(1+np.exp(z))

# %%
w

sigmoid(linear(w111,w121,b31,))
